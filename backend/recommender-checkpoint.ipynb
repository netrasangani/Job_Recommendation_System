# %%
import pandas as pd

# %%
df = pd.read_csv('df.csv')

# %%
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
import numpy as np
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
import numpy as np
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Initialize the Porter Stemmer
port_stem = PorterStemmer()

# Define the preprocessing function
def preprocessing(content):
    stemmed_content = re.sub('[^a-zA-Z]', ' ', content)
    stemmed_content = stemmed_content.lower()
    stemmed_content = stemmed_content.split()
    stemmed_content = [port_stem.stem(word) for word in stemmed_content if word not in stopwords.words('english')]
    stemmed_content = ' '.join(stemmed_content)
    return stemmed_content

# Collect user input
user_input = input("Enter your text: ")

# Preprocess the user input
processed_input = preprocessing(user_input)


# Vectorize the user input
user_input_vector = vectorizer.transform([processed_input])

# Compute cosine similarity
similarity_matrix = cosine_similarity(user_input_vector, X)

top_indices = np.argsort(similarity_matrix[0])[-15:][::-1]
top_similarities = similarity_matrix[0, top_indices]

# Print the results
print("Top 15 Most Similar Documents:")
for index, score in zip(top_indices, top_similarities):
    print(f"Index: {index}, Similarity Score: {score:.4f}")
    print(f"Document: {df.iloc[index]['tags']}")
    print()
# Out:
# Enter your text:  Write a poem about a robot who dreams of becoming a gardener.
# Top 15 Most Similar Documents:
# Index: 3080, Similarity Score: 0.3125
# Document: transmedia write michigan state univers advanc fiction write film write determin adapt screenwrit dialogu game design grammar dream interpret art humaniti histori art human
#
# Index: 2042, Similarity Score: 0.2729
# Document: modern robot cours capston project mobil manipul northwestern univers advanc comput program jpeg simul robot control robot project feed forward control frame critic think industri robot physic scienc engin mechan engin physic scienc engin
#
# Index: 780, Similarity Score: 0.2594
# Document: modern robot cours robot manipul wheel mobil robot northwestern univers advanc normal geometri order pair linear span c process control convex hull robot optim control motion plan convex set short path problem physic scienc engin mechan engin physic scienc engin
#
# Index: 407, Similarity Score: 0.2147
# ...

# %%
import pickle

# %%
vectorizer = TfidfVectorizer(
    stop_words='english', 
    min_df=2,
    max_df=0.8            
)
X = vectorizer.fit_transform(df['tags'])

# %%
pickle.dump(similarity_matrix,open('similarity1.pkl','wb'))

# %%
df['info'][0]
# Out:
# "{id: 1, name: 'Write feature length screenplay film television', university: 'Michigan State University', level: 'Beginner', rating: '4.8', url: 'https://www.coursera.org/learn/write-a-feature-length-screenplay-for-film-or-television', description: 'Write full length feature film script course write complete feature length screenplay film television serious drama romantic comedy anything learn break creative process component discover structured process allow produce polished pitch ready script end course complete project increase confidence idea ability feel prepared pitch first script get start next course design tap creativity base active learn actual learning take place within activity write learn link trailer course view trailer please copy paste link browser https vimeocom b b dc learner review love approach professor wheeler take towards course point easy follow informative would definitely recommend anyone interested take screenplay writing course course curriculum simple ad
# ...

# %%
pickle.dump(vectorizer,open('vectorizer_courses.pkl','wb'))

# %% [markdown]
# # Going for the jobs

# %%
import pandas as pd

# %%
jobs = pd.read_csv('finaljob.csv')

# %%
jobs
# Out:
#          Unnamed: 0.1  Unnamed: 0 Job Posting Date            Country  \
# 0                   0           0       2022-04-24        isle of man
# 1                   1           1       2022-12-19       turkmenistan
# 2                   2           2       2022-09-14   macao sar, china
# 3                   3           3       2023-02-25              benin
# 4                   4           4       2022-10-11              chile
# ...               ...         ...              ...                ...
# 1610457       1610457     1615935       2022-05-19  equatorial guinea
# 1610458       1610458     1615936       2023-03-14             poland
# 1610459       1610459     1615937       2022-01-23       turkmenistan
# 1610460       1610460     1615938       2021-12-28       burkina faso
# 1610461       1610461     1615939       2022-10-01            eritrea
#
#                   location  Work Type Qualifications     Experience  \
# ...

# %%
df = jobs.sample(500000)

# %%
df = df.drop(columns=['Unnamed: 0.1','Unnamed: 0'])

# %%
df
# Out:
#         Job Posting Date                       Country      location  \
# 950737        2021-12-20                  south africa      pretoria
# 747971        2023-06-06           antigua and barbuda  saint john's
# 372249        2023-08-21                       belgium      brussels
# 1435234       2022-04-29          syrian arab republic      damascus
# 1180502       2023-02-25                       estonia       tallinn
# ...                  ...                           ...           ...
# 42274         2023-06-02  democratic republic of congo      kinshasa
# 1581584       2021-09-28                       nigeria         abuja
# 509933        2022-10-04                   puerto rico      san juan
# 233510        2022-02-17                        guinea       conakry
# 329134        2023-06-26  democratic republic of congo      kinshasa
#
#         Work Type Qualifications     Experience  \
# 950737     intern          btech  4 to 14 Years
# ...

# %%
import pandas as pd
a = pd.read_csv('lastJob.csv')

# %%
a = a.drop(columns=['Unnamed: 0'])

# %%
companies = a

# %%
companies
# Out:
#               id                                               tags  \
# 0              1  intern m.tech social media platform facebook t...
# 1              2  intern bca html css javascript frontend framew...
# 2              3  temporary phd qualiti control process methodol...
# 3              4  full-time phd wireless network design architec...
# 4              5  intern mba event plan confer logist budget man...
# ...          ...                                                ...
# 1610458  1610459  intern m.tech strateg plan leadership manag bu...
# 1610459  1610460  part-time bca mechan engin cad softwar solidwo...
# 1610460  1610461  full-time bca train program coordin train mate...
# 1610461  1610462  part-time bba wed plan venu select cater menu ...
# 1610462  1610463  0          [intern, tech, social, media, platf...
#
#                                                       Info
# 0        {"Sector": "Diversified", "Industry": "Diversi...
# ...

# %%
recommend_df = companies.sample(500000)

# %%
recommend_df.to_csv('jobs_dataset.csv')

# %%
recommend_df = recommend_df.reset_index(drop=True)

# %%
recommend_df
# Out:
#              id                                               tags  \
# 0        265220  part-time m.com email market strategi email ma...
# 1       1602425  contract mba environment complianc regulatori ...
# 2        206315  full-time mba retir plan social secur invest p...
# 3        119947  intern bca financi plan invest strategi team l...
# 4          6640  temporary phd product design principl prototyp...
# ...         ...                                                ...
# 499995   524760  contract mca social scienc research method qua...
# 499996   473929  full-time bca counsel techniqu psychotherapi m...
# 499997  1514465  contract bba treasuri manag cash flow analysi ...
# 499998  1167724  part-time b.com solut design technic architect...
# 499999   956094  temporary bba wed plan venu select cater menu ...
#
#                                                      Info
# 0       {"Sector": "Utilities", "Industry": "Utilities...
# ...

# %%
recommend_df['tags'][0]
# Out:
# 'part-time m.com email market strategi email market platform mailchimp hubspot audienc segment test campaign analyt copywrit html css email market autom commun skill data analysi attent detail plan execut analyz email market campaign engag subscrib increas convers build brand awar email marketing specialist email campaign manager'

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
vectorizer = TfidfVectorizer(
    stop_words='english', 
    min_df=2,
    max_df=0.8            
)
X = vectorizer.fit_transform(recommend_df['tags'])

# %%
from sklearn.metrics.pairwise import cosine_similarity
